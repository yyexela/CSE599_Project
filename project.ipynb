# %% [markdown]
# ### Imports

# %%
# Reload external files when running cells
# %load_ext autoreload
# %autoreload 2

# Imports
import torch
from torch import nn
import numpy as np
import pathlib
import os
import sys
import matplotlib.pyplot as plt
import pathlib

# Add custom package to import path and import it
file_dir = pathlib.Path().resolve()
pkg_dir = os.path.join(file_dir, "submodules")
sys.path.insert(0, pkg_dir)
sys.path.insert(0, os.path.join(pkg_dir, "helper_pkg"))
from helper_pkg.src import *

# Load config file
config = helpers.get_config()
config['top_dir'] = "General"

# Make dirs for plots
pathlib.Path(os.path.join(file_dir, config['top_dir'])).mkdir(parents=True, exist_ok=True)
pathlib.Path(os.path.join(file_dir, config['top_dir'], 'Plots')).mkdir(parents=True, exist_ok=True)

# Set seeds
np.random.seed(config['np_seed'])
torch.manual_seed(config['torch_seed'])

# Print matplotlib plots inline
# %matplotlib inline

# Make sure Torch is installed and see if a GPU is available
print("GPU Available?",torch.cuda.is_available())
device = "cpu"
if torch.cuda.is_available():
    device = "cuda"
# Out:
# GPU Available? True

# %% [markdown]
# ### Print CIFAR10 sample data

# %%
config['dataset'] = 'CIFAR10'
config['input_dim'] = config[config['dataset']]['input_dim']
config['hidden_layers'] = config[config['dataset']]['hidden_layers']
config['hidden_dim'] = config[config['dataset']]['hidden_dim']
config['output_dim'] = config[config['dataset']]['output_dim']
config['scale'] = 0
config['input_channels'] = config[config['dataset']]['input_channels']

train_ds_wrapped, test_ds_wrapped = datasets.load_wrapped_datasets(new_labels="none")
helpers.plot_sample(config['dataset'], train_ds_wrapped, 'CIFAR10_Original.pdf')
# Out:
# Using dataset CIFAR10
# Files already downloaded and verified
# Files already downloaded and verified
# batch shape:
# torch.Size([8192, 3, 32, 32])
# torch.Size([8192])
# Image size: torch.Size([3, 32, 32])
# Saved plot to "/home/alexey/School/Classes/CSE 542/Project/General/Plots/CIFAR10_Original.pdf"

# %%
config['dataset'] = 'CIFAR10'
config['input_dim'] = config[config['dataset']]['input_dim']
config['hidden_layers'] = config[config['dataset']]['hidden_layers']
config['hidden_dim'] = config[config['dataset']]['hidden_dim']
config['output_dim'] = config[config['dataset']]['output_dim']
config['scale'] = 0
config['input_channels'] = config[config['dataset']]['input_channels']

train_ds_wrapped, test_ds_wrapped = datasets.load_wrapped_datasets(new_labels="shuffle_class")
helpers.plot_sample(config['dataset'], train_ds_wrapped, 'CIFAR10_ClassShuffle.pdf')
# Out:
# Using dataset CIFAR10
# Files already downloaded and verified
# Files already downloaded and verified
# batch shape:
# torch.Size([8192, 3, 32, 32])
# torch.Size([8192])
# Image size: torch.Size([3, 32, 32])
# Saved plot to "/home/alexey/School/Classes/CSE 542/Project/General/Plots/CIFAR10_ClassShuffle.pdf"

# %%
config['dataset'] = 'CIFAR10'
config['input_dim'] = config[config['dataset']]['input_dim']
config['hidden_layers'] = config[config['dataset']]['hidden_layers']
config['hidden_dim'] = config[config['dataset']]['hidden_dim']
config['output_dim'] = config[config['dataset']]['output_dim']
config['scale'] = 0
config['input_channels'] = config[config['dataset']]['input_channels']

train_ds_wrapped, test_ds_wrapped = datasets.load_wrapped_datasets(new_labels="shuffle_full")
helpers.plot_sample(config['dataset'], train_ds_wrapped, 'CIFAR10_FullShuffle.pdf')
# Out:
# Using dataset CIFAR10
# Files already downloaded and verified
# Files already downloaded and verified
# batch shape:
# torch.Size([8192, 3, 32, 32])
# torch.Size([8192])
# Image size: torch.Size([3, 32, 32])
# Saved plot to "/home/alexey/School/Classes/CSE 542/Project/General/Plots/CIFAR10_FullShuffle.pdf"

# %% [markdown]
# ### Print MNIST sample data

# %%
config['dataset'] = 'MNIST'
config['input_dim'] = config[config['dataset']]['input_dim']
config['hidden_layers'] = config[config['dataset']]['hidden_layers']
config['hidden_dim'] = config[config['dataset']]['hidden_dim']
config['output_dim'] = config[config['dataset']]['output_dim']

train_ds_wrapped, test_ds_wrapped = datasets.load_wrapped_datasets(new_labels="none")
helpers.plot_sample("MNIST", train_ds_wrapped, 'MNIST_Original.pdf')
# Out:
# Using dataset MNIST
# batch shape:
# torch.Size([8192, 1, 28, 28])
# torch.Size([8192])
# Image size: torch.Size([1, 28, 28])
# Saved plot to "/home/alexey/School/Classes/CSE 542/Project/General/Plots/MNIST_Original.pdf"

# %%
config['dataset'] = 'MNIST'
config['input_dim'] = config[config['dataset']]['input_dim']
config['hidden_layers'] = config[config['dataset']]['hidden_layers']
config['hidden_dim'] = config[config['dataset']]['hidden_dim']
config['output_dim'] = config[config['dataset']]['output_dim']

train_ds_wrapped, test_ds_wrapped = datasets.load_wrapped_datasets(new_labels="shuffle_class")
helpers.plot_sample("MNIST", train_ds_wrapped, 'MNIST_ClassShuffle.pdf')
# Out:
# Using dataset MNIST
# batch shape:
# torch.Size([8192, 1, 28, 28])
# torch.Size([8192])
# Image size: torch.Size([1, 28, 28])
# Saved plot to "/home/alexey/School/Classes/CSE 542/Project/General/Plots/MNIST_ClassShuffle.pdf"

# %%
config['dataset'] = 'MNIST'
config['input_dim'] = config[config['dataset']]['input_dim']
config['hidden_layers'] = config[config['dataset']]['hidden_layers']
config['hidden_dim'] = config[config['dataset']]['hidden_dim']
config['output_dim'] = config[config['dataset']]['output_dim']

train_ds_wrapped, test_ds_wrapped = datasets.load_wrapped_datasets(new_labels="shuffle_full")
helpers.plot_sample(config['dataset'], train_ds_wrapped, 'MNIST_FullShuffle.pdf')
# Out:
# Using dataset MNIST
# batch shape:
# torch.Size([8192, 1, 28, 28])
# torch.Size([8192])
# Image size: torch.Size([1, 28, 28])
# Saved plot to "/home/alexey/School/Classes/CSE 542/Project/General/Plots/MNIST_FullShuffle.pdf"
